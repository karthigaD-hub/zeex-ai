# %%
model.train(
    data="D:/projects/zeex-fire-detect/data/processed/fire_smoke_yolo/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device=0,     # GPU (or use device='cpu')
    name="fire_smoke_detect"
)

# %%
pip install ultralytics
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")  # small model
